# %% [markdown]
# <a href="https://colab.research.google.com/github/youraveragefightingfrenchman/CS1---PYTHON---DIAMOND---HERRERA/blob/MAIN-BRANCH/cs1_python_herrera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello Grade 7!")
# Out:
# Hello Grade 7!
