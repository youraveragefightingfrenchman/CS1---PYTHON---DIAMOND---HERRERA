# %% [markdown]
# <a href="https://colab.research.google.com/github/youraveragefightingfrenchman/CS1---PYTHON---DIAMOND---HERRERA/blob/MAIN-BRANCH/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Enter first  number"))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))
if (num1 >= num2) and (num2 >= num3):biggest = num1
elif (num2 >= num1) and (num2 >= num3): biggest = num2
else:
   biggest = num3
   print("The  biggest number is", biggest)
# Out:
# Enter first  number 6
# Enter second number:  7
# Enter third number: 90
# The  biggest number is 90
